# %% [markdown]
# # Earthquake Visualization Project

# %%
from google.colab import files
import numpy as np
import io
import pandas as pd

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-020c6f98-cb1f-4374-908d-6f2c7b52c081" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-020c6f98-cb1f-4374-908d-6f2c7b52c081">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving earthquake .csv to earthquake  (1).csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['earthquake .csv']))

# %%
df = df.drop(columns = ['horizontalError',
                        'depthError',
                        'magError',
                        'magNst',
                        'status',
                        'locationSource',
                        'magSource',
                        'magType',
                        'nst'])

# %%
df
# Out:
#                           time  ...        type
# 0     2021-05-21T18:04:13.537Z  ...  earthquake
# 1     2021-03-20T09:09:43.966Z  ...  earthquake
# 2     2021-03-04T19:28:33.178Z  ...  earthquake
# 3     2021-03-04T17:41:23.370Z  ...  earthquake
# 4     2021-03-04T13:27:34.647Z  ...  earthquake
# ...                        ...  ...         ...
# 1418  1901-08-09T18:33:00.000Z  ...  earthquake
# 1419  1901-08-09T13:01:00.000Z  ...  earthquake
# 1420  1900-10-29T09:11:00.000Z  ...  earthquake
# 1421  1900-10-09T12:25:00.000Z  ...  earthquake
# 1422  1900-07-29T06:59:00.000Z  ...  earthquake
#
# [1423 rows x 13 columns]

# %% [markdown]
# Which place had the most earthquakes

# %%
places = df['place'].tolist()

# %%
places
# Out:
# ['Southern Qinghai, China',
#  '30 km E of Ishinomaki, Japan',
#  'Kermadec Islands, New Zealand',
#  'Kermadec Islands, New Zealand',
#  '182 km NE of Gisborne, New Zealand',
#  '73 km ENE of Namie, Japan',
#  'southeast of the Loyalty Islands',
#  '211 km SE of Pondaguitan, Philippines',
#  '13 km NNE of Néon Karlovásion, Greece',
#  '99 km SE of Sand Point, Alaska',
#  '99 km SSE of Perryville, Alaska',
#  '114 km NNW of Popondetta, Papua New Guinea',
#  '9 km SE of Santa María Xadani, Mexico',
#  'south of the Kermadec Islands',
#  "221km SSE of Severo-Kuril'sk, Russia",
#  "94km ENE of Kuril'sk, Russia",
#  '123km NNW of Lucea, Jamaica',
#  '138km E of Bitung, Indonesia',
#  '93km NNE of Laiwui, Indonesia',
#  '2019 Ridgecrest Earthquake Sequence',
#  '292km NW of Saumlaki, Indonesia',
#  "116km NE of L'Esperance Rock, New Zealand",
#  '78km SE of Lagunas, Peru',
#  '46km SSE of Namatanai, Papua New Guinea',
#  '33km NW of Bulolo, Papua New Guinea',
#  '23km NNE of Azangaro, Peru',
#  '111km ESE of Palora, Ecuador',
#  '96km ESE of Pondaguitan, Philippines',
#  "83km W of Nikol'skoye, Russia",
#  '54km N of Bristol Island, South Sandwich Islands',
#  '165km ESE of Tadine, New Caledonia',
#  '14km NNW of Anchorage, Alaska',
#  '118km E of Kimbe, Papua New Guinea',
#  '70km N of Palu, Indonesia',
#  '102km ESE of Suva, Fiji',
#  '202km WNW of Ile Hunter, New Caledonia',
#  '140km WNW of Iberia, Peru',
#  '24km ENE of Rio Caribe, Venezuela',
#  '286km NNE of Ndoi Island, Fiji',
#  '83km SW of Porgera, Papua New Guinea',
#  '3km S of San Pedro Jicayan, Mexico',
#  '280km SE of Kodiak, Alaska',
#  '38km SSW of Acari, Peru',
#  '44km E of Great Swan Island, Honduras',
#  '85km ENE of Tadine, New Caledonia',
#  '29km S of Halabjah, Iraq',
#  '1km E of Ayutla, Mexico',
#  '101km SSW of Tres Picos, Mexico',
#  "202km ESE of Nikol'skoye, Russia",
#  '35km WNW of Panguna, Papua New Guinea',
#  '189km SSE of Tabiauan, Philippines',
#  '41km SW of Puerto Quellon, Chile',
#  '54km E of Taron, Papua New Guinea',
#  '69km WSW of Kirakira, Solomon Islands',
#  '54km NNE of Amberley, New Zealand',
#  '175km NE of Gisborne, New Zealand',
#  'North of Ascension Island',
#  'South Georgia Island region',
#  '110km E of Ile Hunter, New Caledonia',
#  '29km SW of Agrihan, Northern Mariana Islands',
#  '53km NNE of Visokoi Island, South Georgia and the South Sandwich Islands',
#  '2km N of Norsup, Vanuatu',
#  '27km SSE of Muisne, Ecuador',
#  '1km E of Kumamoto-shi, Japan',
#  'Southwest of Sumatra, Indonesia',
#  '88km N of Yelizovo, Russia',
#  '86km E of Old Iliamna, Alaska',
#  '104km W of Murghob, Tajikistan',
#  'Southeast Indian Ridge',
#  '211km S of Tarauaca, Brazil',
#  '173km WNW of Iberia, Peru',
#  '45km E of Farkhar, Afghanistan',
#  '34km NE of Port-Olry, Vanuatu',
#  '25km WNW of Illapel, Chile',
#  '48km W of Illapel, Chile',
#  '228km W of Abepura, Indonesia',
#  '83km WNW of Lata, Solomon Islands',
#  'Southern Mid-Atlantic Ridge',
#  '189km WNW of Chichi-shima, Japan',
#  '19km SE of Kodari, Nepal',
#  '143km SW of Panguna, Papua New Guinea',
#  '130km SSW of Kokopo, Papua New Guinea',
#  '36km E of Khudi, Nepal',
#  '53km SE of Kokopo, Papua New Guinea',
#  '130km N of Nebe, Indonesia',
#  'Northern Mid-Atlantic Ridge',
#  '154km NW of Kota Ternate, Indonesia',
#  '144km NE of Ndoi Island, Fiji',
#  '74km S of Intipuca, El Salvador',
#  'Southern East Pacific Rise',
#  '19km SE of Little Sitkin Island, Alaska',
#  '70km SW of Panguna, Papua New Guinea',
#  '33km ESE of Petatlan, Mexico',
#  '112km S of Kirakira, Solomon Islands',
#  '93km SSE of Kirakira, Solomon Islands',
#  '56km WSW of Panguna, Papua New Guinea',
#  '53km SW of Iquique, Chile',
#  '94km NW of Iquique, Chile',
#  'Falkland Islands region',
#  'Scotia Sea',
#  'Off the east coast of Honshu, Japan',
#  '4km SE of Sagbayan, Philippines',
#  '46km SSE of Acari, Peru',
#  '61km NNE of Awaran, Pakistan',
#  '101km SW of Atka, Alaska',
#  '218km SSE of Bristol Island, South Sandwich Islands',
#  '115km ENE of Taron, Papua New Guinea',
#  'Sea of Okhotsk',
#  '282km SW of Vaini, Tonga',
#  "251km ENE of Kuril'sk, Russia",
#  '83km E of Khash, Iran',
#  '240km E of Enarotali, Indonesia',
#  '31km SE of Lata, Solomon Islands',
#  '27km NNW of Lata, Solomon Islands',
#  '114km WSW of Lata, Solomon Islands',
#  '76km W of Lata, Solomon Islands',
#  'Southeastern Alaska',
#  'Banda Sea',
#  'off the east coast of Honshu, Japan',
#  'offshore Guatemala',
#  'Haida Gwaii, Canada',
#  'Colombia',
#  'Costa Rica',
#  'Philippine Islands region',
#  'off the coast of El Salvador',
#  'Sea of Okhotsk',
#  'Baja California, Mexico',
#  'off the west coast of northern Sumatra',
#  'off the west coast of northern Sumatra',
#  'Maule, Chile',
#  'Oaxaca, Mexico',
#  'Vanuatu',
#  'off the west coast of northern Sumatra',
#  'eastern New Guinea region, Papua New Guinea',
#  'eastern Turkey',
#  'Kermadec Islands region',
#  'Fiji region',
#  'Vanuatu',
#  'northern Peru',
#  'Vanuatu',
#  'Vanuatu',
#  'off the east coast of Honshu, Japan',
#  'Kermadec Islands region',
#  'Fox Islands, Aleutian Islands, Alaska',
#  'near the east coast of Honshu, Japan',
#  'off the east coast of Honshu, Japan',
#  'near the east coast of Honshu, Japan',
#  '2011 Great Tohoku Earthquake, Japan',
#  'near the east coast of Honshu, Japan',
#  'southwestern Pakistan',
#  'Loyalty Islands, New Caledonia',
#  'Araucania, Chile',
#  'Santiago Del Estero, Argentina',
#  'Vanuatu region',
#  'Bonin Islands, Japan region',
#  'Kepulauan Mentawai region, Indonesia',
#  'near the south coast of Papua, Indonesia',
#  'South Island of New Zealand',
#  'Ecuador',
#  'Vanuatu',
#  'New Britain region, Papua New Guinea',
#  'Moro Gulf, Mindanao, Philippines',
#  'Moro Gulf, Mindanao, Philippines',
#  'Moro Gulf, Mindanao, Philippines',
#  'New Britain region, Papua New Guinea',
#  'near the north coast of Papua, Indonesia',
#  'Nicobar Islands, India region',
#  'Vanuatu',
#  'northern Sumatra, Indonesia',
#  'northern Sumatra, Indonesia',
#  '12km SW of Delta, B.C., MX',
#  "Libertador General Bernardo O'Higgins, Chile",
#  'off the coast of Bio-Bio, Chile',
#  'offshore Bio-Bio, Chile',
#  'Ryukyu Islands, Japan',
#  'Haiti region',
#  'Solomon Islands',
#  'Fiji',
#  'Vanuatu',
#  'Santa Cruz Islands',
#  'Vanuatu',
#  'southern Sumatra, Indonesia',
#  'Samoa Islands region',
#  'Java, Indonesia',
#  'Andaman Islands, India region',
#  'near the south coast of Honshu, Japan',
#  'off the west coast of the South Island of New Zealand',
#  'offshore Honduras',
#  'Tonga region',
#  'Kermadec Islands region',
#  'Kepulauan Talaud, Indonesia',
#  'east of the Kuril Islands',
#  'near the north coast of Papua, Indonesia',
#  'near the north coast of Papua, Indonesia',
#  'Sea of Okhotsk',
#  'Minahasa, Sulawesi, Indonesia',
#  'Kermadec Islands, New Zealand',
#  'off the east coast of Honshu, Japan',
#  'Sea of Okhotsk',
#  'South Sandwich Islands region',
#  'eastern Sichuan, China',
#  'Macquarie Island region',
#  'Loyalty Islands, New Caledonia',
#  'Xinjiang-Xizang border region',
#  'Kepulauan Mentawai region, Indonesia',
#  'Simeulue, Indonesia',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'south of the Fiji Islands',
#  'Martinique region, Windward Islands',
#  'Antofagasta, Chile',
#  'Pagan region, Northern Mariana Islands',
#  'Auckland Islands, New Zealand region',
#  'Volcano Islands, Japan region',
#  'Kepulauan Mentawai region, Indonesia',
#  'Kepulauan Mentawai region, Indonesia',
#  'southern Sumatra, Indonesia',
#  'Santa Cruz Islands',
#  'near the coast of central Peru',
#  'Java, Indonesia',
#  'Vanuatu',
#  'Solomon Islands',
#  'Vanuatu',
#  'Molucca Sea',
#  'east of the Kuril Islands',
#  'Taiwan region',
#  'Kuril Islands',
#  'Scotia Sea',
#  'south of Java, Indonesia',
#  'Kermadec Islands region',
#  'Tonga',
#  'near the east coast of Koryakskiy Avtonomnyy Okrug, Russia',
#  'Mozambique',
#  'Banda Sea',
#  'Fiji region',
#  'east of the South Sandwich Islands',
#  'off the east coast of Honshu, Japan',
#  'Pakistan',
#  'northern Peru',
#  'New Ireland region, Papua New Guinea',
#  'near the east coast of Honshu, Japan',
#  'Nicobar Islands, India region',
#  'off the coast of Northern California',
#  'Tarapaca, Chile',
#  'northern Sumatra, Indonesia',
#  'Banda Sea',
#  'Celebes Sea',
#  'Nicobar Islands, India region',
#  '2004 Sumatra - Andaman Islands Earthquake',
#  'north of Macquarie Island',
#  'Hokkaido, Japan region',
#  'Papua, Indonesia',
#  'off the west coast of the South Island of New Zealand',
#  'near the west coast of Colombia',
#  'Kepulauan Alor, Indonesia',
#  'near the coast of Nicaragua',
#  'near the south coast of Honshu, Japan',
#  'near the south coast of western Honshu, Japan',
#  'southern Sumatra, Indonesia',
#  'Fiji region',
#  'near the south coast of Papua, Indonesia',
#  'Papua, Indonesia',
#  'southeast of the Loyalty Islands',
#  'southeast of the Loyalty Islands',
#  'Rat Islands, Aleutian Islands, Alaska',
#  'off the east coast of Honshu, Japan',
#  'southwestern Siberia, Russia',
#  'Hokkaido, Japan region',
#  'Hokkaido, Japan region',
#  'South Island of New Zealand',
#  'Scotia Sea',
#  'Carlsberg Ridge',
#  'Amazonas, Brazil',
#  'Halmahera, Indonesia',
#  'near the east coast of Honshu, Japan',
#  'Rat Islands, Aleutian Islands, Alaska',
#  'Rat Islands, Aleutian Islands, Alaska',
#  'offshore Colima, Mexico',
#  'Solomon Islands',
#  'northwest of the Kuril Islands',
#  'Central Alaska',
#  'Simeulue, Indonesia',
#  'near the north coast of Papua, Indonesia',
#  'near the north coast of New Guinea, Papua New Guinea',
#  'south of the Fiji Islands',
#  'Fiji region',
#  'Jilin-Heilongjiang border region, China',
#  'Guam region',
#  'Taiwan region',
#  'Mindanao, Philippines',
#  'Hindu Kush region, Afghanistan',
#  'Vanuatu',
#  'south of Australia',
#  'southern Qinghai, China',
#  'New Britain region, Papua New Guinea',
#  'Banda Sea',
#  'Guam region',
#  'east of the North Island of New Zealand',
#  'near the coast of southern Peru',
#  'near the coast of southern Peru',
#  'Kermadec Islands, New Zealand',
#  'Molucca Sea',
#  'southern Sumatra, Indonesia',
#  'Gujarat, India',
#  'offshore El Salvador',
#  'Vanuatu',
#  'Mindanao, Philippines',
#  'Turkmenistan',
#  'New Britain region, Papua New Guinea',
#  'New Ireland region, Papua New Guinea',
#  'New Ireland region, Papua New Guinea',
#  'New Ireland region, Papua New Guinea',
#  'Vanuatu',
#  'Bonin Islands, Japan region',
#  'South Indian Ocean',
#  'southern Sumatra, Indonesia',
#  'Jujuy, Argentina',
#  'Sulawesi, Indonesia',
#  'Santiago Del Estero, Argentina',
#  'Volcano Islands, Japan region',
#  'Vanuatu region',
#  'Tonga',
#  'Luzon, Philippines',
#  'Kodiak Island region, Alaska',
#  'Vanuatu',
#  'New Britain region, Papua New Guinea',
#  'South Indian Ocean',
#  'western Turkey',
#  'Hector Mine, CA Earthquake',
#  'Oaxaca, Mexico',
#  'Taiwan',
#  'western Turkey',
#  'Puebla, Mexico',
#  'New Britain region, Papua New Guinea',
#  'New Britain region, Papua New Guinea',
#  'Jilin-Heilongjiang border region, China',
#  'New Britain region, Papua New Guinea',
#  'Sulu Archipelago, Philippines',
#  'Santa Cruz Islands',
#  'New Ireland region, Papua New Guinea',
#  'Banda Sea',
#  'Banda Sea',
#  'Bonin Islands, Japan region',
#  'near the coast of Ecuador',
#  'near the north coast of New Guinea, Papua New Guinea',
#  'Santa Cruz Islands',
#  'southeast of Taiwan',
#  'southern Sumatra, Indonesia',
#  'Fiji region',
#  'Balleny Islands region',
#  'Antofagasta, Chile',
#  'southeast of the Loyalty Islands',
#  'eastern New Guinea region, Papua New Guinea',
#  'near the east coast of the Kamchatka Peninsula, Russia',
#  'Minahasa, Sulawesi, Indonesia',
#  'Vanuatu',
#  'western Xizang',
#  'northern Peru',
#  'Coquimbo, Chile',
#  'south of the Fiji Islands',
#  'Kermadec Islands region',
#  'Sucre, Venezuela',
#  'south of the Kermadec Islands',
#  'eastern Iran',
#  'Santa Cruz Islands',
#  'Pakistan',
#  'Potosi, Bolivia',
#  'Michoacan, Mexico',
#  'near the coast of central Peru',
#  'Fiji region',
#  'Minahasa, Sulawesi, Indonesia',
#  'Flores Sea',
#  'Samar, Philippines',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'northern Mid-Atlantic Ridge',
#  'Bougainville region, Papua New Guinea',
#  'south of the Fiji Islands',
#  'offshore Oaxaca, Mexico',
#  'off the coast of northern Peru',
#  'Biak region, Indonesia',
#  'Kuril Islands',
#  'Minahasa, Sulawesi, Indonesia',
#  'Banda Sea',
#  'Kuril Islands',
#  'Egypt',
#  'Chiapas, Mexico',
#  'Ryukyu Islands, Japan',
#  'Colima, Mexico',
#  'Peru-Ecuador border region',
#  'Guerrero, Mexico',
#  'Pagan region, Northern Mariana Islands',
#  'Bougainville region, Papua New Guinea',
#  'Bougainville region, Papua New Guinea',
#  'Antofagasta, Chile',
#  'Kermadec Islands, New Zealand',
#  'Sakhalin, Russia',
#  'southeast of the Loyalty Islands',
#  'Samar, Philippines',
#  'Samar, Philippines',
#  'Tonga',
#  'off the east coast of the North Island of New Zealand',
#  'near the east coast of Honshu, Japan',
#  'off the east coast of Honshu, Japan',
#  'Mindoro, Philippines',
#  'Kuril Islands',
#  'Kuril Islands',
#  'off the coast of Northern California',
#  "Primor'ye, Russia",
#  'Vanuatu',
#  'La Paz, Bolivia',
#  'south of Java, Indonesia',
#  'central Mid-Atlantic Ridge',
#  'Fiji region',
#  'Vanuatu',
#  'Halmahera, Indonesia',
#  'Vanuatu',
#  'near the east coast of the Kamchatka Peninsula, Russia',
#  'offshore Chiapas, Mexico',
#  'off the west coast of the South Island of New Zealand',
#  'Hindu Kush region, Afghanistan',
#  'Guam region',
#  'Hokkaido, Japan region',
#  'near the east coast of the Kamchatka Peninsula, Russia',
#  'Jujuy, Argentina',
#  'Mindanao, Philippines',
#  'Santa Cruz Islands region',
#  'Hokkaido, Japan region',
#  'Banda Sea',
#  'Flores region, Indonesia',
#  'northern Colombia',
#  'Vanuatu',
#  'near the coast of Nicaragua',
#  'Kyrgyzstan',
#  'south of the Fiji Islands',
#  'Landers, California Earthquake',
#  'Santa Cruz Islands',
#  'Mindanao, Philippines',
#  'Mindanao, Philippines',
#  'eastern New Guinea region, Papua New Guinea',
#  '20km SSW of Rio Dell, California',
#  'South Sandwich Islands region',
#  'Kuril Islands',
#  'near the west coast of Colombia',
#  'Solomon Islands',
#  'Fiji region',
#  '136km WSW of Brookings, Oregon',
#  'central Peru',
#  'Santiago Del Estero, Argentina',
#  'Minahasa, Sulawesi, Indonesia',
#  'Fiji region',
#  'Alaska Peninsula',
#  'Minahasa, Sulawesi, Indonesia',
#  "Georgia (Sak'art'velo)",
#  'Costa Rica',
#  'northern Peru',
#  'Mindanao, Philippines',
#  'Myanmar',
#  'New Britain region, Papua New Guinea',
#  'Komandorskiye Ostrova, Russia region',
#  'Peru-Brazil border region',
#  'Vanuatu',
#  'Vanuatu',
#  'Luzon, Philippines',
#  'northern Iran',
#  'Panay, Philippines',
#  'Romania',
#  'Flores Sea',
#  'Sudan',
#  'Sudan',
#  'Tatar Strait, Russia',
#  'Minahasa, Sulawesi, Indonesia',
#  'Mariana Islands region',
#  'Costa Rica',
#  'Vanuatu',
#  'south of the Fiji Islands',
#  'Mindanao, Philippines',
#  'eastern New Guinea region, Papua New Guinea',
#  'near the east coast of Honshu, Japan',
#  '164 km SE of Chignik, Alaska',
#  'Macquarie Island region',
#  'Kermadec Islands, New Zealand',
#  'Acre, Brazil',
#  'Molucca Sea',
#  'Myanmar-China border region',
#  'Tonga region',
#  'Solomon Islands',
#  'Myanmar',
#  'Kepulauan Aru region, Indonesia',
#  'New Britain region, Papua New Guinea',
#  'near the coast of southern Peru',
#  'Gulf of Alaska',
#  'Catanduanes, Philippines',
#  'Antofagasta, Chile',
#  'Antofagasta, Chile',
#  'Gulf of Alaska',
#  'New Britain region, Papua New Guinea',
#  'Bougainville region, Papua New Guinea',
#  'Tonga region',
#  'Macquarie Island region',
#  'Tarapaca, Chile',
#  'Banda Sea',
#  'Jujuy, Argentina',
#  'Colombia-Ecuador border region',
#  'near the coast of Antofagasta, Chile',
#  'Antofagasta, Chile',
#  'eastern New Guinea region, Papua New Guinea',
#  'South Sandwich Islands region',
#  'Taiwan',
#  'Fiji region',
#  'Kermadec Islands region',
#  'Romania',
#  'Molucca Sea',
#  'New Guinea, Papua New Guinea',
#  'south of the Fiji Islands',
#  'south of the Fiji Islands',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'Michoacan, Mexico',
#  'southeast of the Loyalty Islands',
#  'Vanuatu',
#  'Vanuatu',
#  'Vanuatu',
#  'near the north coast of Papua, Indonesia',
#  'Guerrero, Mexico',
#  'Michoacan, Mexico',
#  'southern Xinjiang, China',
#  'Hindu Kush region, Afghanistan',
#  'New Britain region, Papua New Guinea',
#  'New Britain region, Papua New Guinea',
#  'Luzon, Philippines',
#  'Molucca Sea',
#  "Libertador General Bernardo O'Higgins, Chile",
#  'Valparaiso, Chile',
#  'offshore Valparaiso, Chile',
#  'Mindanao, Philippines',
#  'Nias region, Indonesia',
#  'southeast of the Loyalty Islands',
#  'central Mid-Atlantic Ridge',
#  'Tonga',
#  'Sulawesi, Indonesia',
#  'New Britain region, Papua New Guinea',
#  'Kuril Islands',
#  'western Uzbekistan',
#  'Izu Islands, Japan region',
#  'Mindanao, Philippines',
#  'Solomon Islands',
#  'Sulawesi, Indonesia',
#  'near the south coast of western Honshu, Japan',
#  'Hindu Kush region, Afghanistan',
#  'offshore Guatemala',
#  'Chagos Archipelago region',
#  'Kepulauan Barat Daya, Indonesia',
#  'South Sandwich Islands region',
#  'Atacama, Chile',
#  'near the east coast of the Kamchatka Peninsula, Russia',
#  'near the west coast of Honshu, Japan',
#  'Iran-Pakistan border region',
#  'Peru-Ecuador border region',
#  'Costa Rica',
#  'New Ireland region, Papua New Guinea',
#  'Kermadec Islands region',
#  'Greece',
#  'south of Tonga',
#  'Santa Cruz Islands',
#  'near the east coast of Honshu, Japan',
#  'north of Macquarie Island',
#  'west of the Bonin Islands, Japan',
#  'offshore El Salvador',
#  'Guerrero, Mexico',
#  'Catanduanes, Philippines',
#  'Kermadec Islands, New Zealand',
#  'Aegean Sea',
#  'Guerrero, Mexico',
#  'off the coast of Valparaiso, Chile',
#  'Samoa Islands region',
#  'eastern Iran',
#  'Vanuatu',
#  'southeast of the Loyalty Islands',
#  'off the west coast of the South Island of New Zealand',
#  'Rat Islands, Aleutian Islands, Alaska',
#  'offshore Northern California',
#  'southeast of the Loyalty Islands',
#  'northern Algeria',
#  'Santa Cruz Islands',
#  'Santa Cruz Islands',
#  'Kuril Islands',
#  'near the coast of Ecuador',
#  'eastern Iran',
#  'Solomon Islands',
#  'off the west coast of the South Island of New Zealand',
#  'Biak region, Indonesia',
#  'Babuyan Islands region, Philippines',
#  'Guerrero, Mexico',
#  'Southern Alaska',
#  'Taiwan region',
#  'Oaxaca, Mexico',
#  'Solomon Islands',
#  'eastern Iran',
#  'Costa Rica',
#  'Taiwan region',
#  'Tonga region',
#  'near the east coast of Honshu, Japan',
#  'Kyrgyzstan',
#  'Kuril Islands',
#  'Kuril Islands',
#  'Kermadec Islands, New Zealand',
#  'San Juan, Argentina',
#  'south of Tonga',
#  'east of the South Sandwich Islands',
#  'south of Sumbawa, Indonesia',
#  'Solomon Islands',
#  'Solomon Islands',
#  'Solomon Islands',
#  'Solomon Islands',
#  'Samoa Islands region',
#  'Luzon, Philippines',
#  'Romania',
#  'Turkey-Iran border region',
#  'Papua, Indonesia',
#  'Mindanao, Philippines',
#  'Hebei, China',
#  'Tianjin-Hebei border region, China',
#  'Panama',
#  'Papua, Indonesia',
#  'northern Sumatra, Indonesia',
#  'Myanmar-China border region',
#  'western Uzbekistan',
#  'western Uzbekistan',
#  'Guatemala',
#  'Kuril Islands',
#  'Kermadec Islands region',
#  'Samoa Islands region',
#  'Hawaii region, Hawaii',
#  'Samar, Philippines',
#  'south of Tonga',
#  'Santa Cruz Islands',
#  'southern Sumatra, Indonesia',
#  'Solomon Islands',
#  'Bougainville region, Papua New Guinea',
#  'Kuril Islands',
#  'Azores-Cape St. Vincent Ridge',
#  'Bio-Bio, Chile',
#  'Liaoning, China',
#  'Near Islands, Aleutian Islands, Alaska',
#  'near the coast of central Peru',
#  "D'Entrecasteaux Islands region",
#  'Antigua and Barbuda region, Leeward Islands',
#  'near the coast of central Peru',
#  'Araucania, Chile',
#  'Kyrgyzstan-Tajikistan-Xinjiang border region',
#  'Panama-Colombia border region',
#  'Kermadec Islands region',
#  'Solomon Islands',
#  'Solomon Islands',
#  'Vanuatu',
#  'Vanuatu',
#  'Vanuatu',
#  'east of the South Sandwich Islands',
#  'Kuril Islands',
#  'Hokkaido, Japan region',
#  'Luzon, Philippines',
#  'Kuril Islands',
#  'western Sichuan, China',
#  'Michoacan, Mexico',
#  'Izu Islands, Japan region',
#  'Mindanao, Philippines',
#  'Loyalty Islands, New Caledonia',
#  'New Britain region, Papua New Guinea',
#  'Southeastern Alaska',
#  'Celebes Sea',
#  'Tonga',
#  'Bougainville region, Papua New Guinea',
#  'Mindoro, Philippines',
#  'Taiwan',
#  'south of the Fiji Islands',
#  'Izu Islands, Japan region',
#  'Santa Cruz Islands',
#  'Taiwan',
#  'Taiwan region',
#  'Vanuatu',
#  'off the east coast of the Kamchatka Peninsula, Russia',
#  'off the east coast of the Kamchatka Peninsula, Russia',
#  'Santa Cruz Islands',
#  'Banda Sea',
#  'Sakhalin, Russia',
#  'Hokkaido, Japan region',
#  'Peru-Ecuador border region',
#  'New Britain region, Papua New Guinea',
#  'New Ireland region, Papua New Guinea',
#  'New Ireland region, Papua New Guinea',
#  'New Ireland region, Papua New Guinea',
#  'Valparaiso, Chile',
#  "Magadanskaya Oblast', Russia",
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'southern Sumatra, Indonesia',
#  'South Shetland Islands',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'Nias region, Indonesia',
#  'Papua, Indonesia',
#  'southern Mid-Atlantic Ridge',
#  'Peru-Ecuador border region',
#  'Solomon Islands',
#  'Sea of Okhotsk',
#  'Colombia',
#  'Myanmar',
#  'Kyushu, Japan',
#  'Haida Gwaii Region, Canada',
#  'Tierra del Fuego, Argentina region',
#  'near the coast of Magallanes, Chile',
#  'Macquarie Island region',
#  'near the coast of northern Peru',
#  'Bonin Islands, Japan region',
#  'offshore Chiapas, Mexico',
#  'Luzon, Philippines',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'Mindanao, Philippines',
#  'Yunnan, China',
#  'east of Dominica, Leeward Islands',
#  'near the east coast of the Kamchatka Peninsula, Russia',
#  'off the west coast of northern Sumatra',
#  'Kuril Islands',
#  'Kuril Islands',
#  'Kyushu, Japan',
#  'Azores-Cape St. Vincent Ridge',
#  'Sulawesi, Indonesia',
#  'Banda Sea',
#  'south of the Fiji Islands',
#  'Kepulauan Talaud, Indonesia',
#  'Vanuatu',
#  'Hokkaido, Japan region',
#  'Solomon Islands',
#  'near the north coast of New Guinea, Papua New Guinea',
#  'Bonin Islands, Japan region',
#  'Kermadec Islands, New Zealand',
#  'northeastern Iran',
#  'Solomon Islands',
#  'Minahasa, Sulawesi, Indonesia',
#  'Molucca Sea',
#  'Oaxaca, Mexico',
#  'Luzon, Philippines',
#  'Kermadec Islands, New Zealand',
#  'off the east coast of Honshu, Japan',
#  'near the north coast of Papua, Indonesia',
#  'South Island of New Zealand',
#  'east of the Kuril Islands',
#  'Kermadec Islands, New Zealand',
#  'Hokkaido, Japan region',
#  'off the east coast of Honshu, Japan',
#  'Shikoku, Japan',
#  'Taiwan region',
#  'Aegean Sea',
#  'New Ireland region, Papua New Guinea',
#  'Kuril Islands',
#  'New Ireland region, Papua New Guinea',
#  'Antofagasta, Chile',
#  'Nicaragua',
#  'Fiji region',
#  'Auckland Islands, New Zealand region',
#  'off the coast of central Peru',
#  'western Turkey',
#  'Peru-Brazil border region',
#  'Reykjanes Ridge',
#  'Colombia',
#  'central Mongolia',
#  'Santa Cruz Islands',
#  'Santa Cruz Islands',
#  'Antofagasta, Chile',
#  'north of Ascension Island',
#  'near the coast of central Peru',
#  'Halmahera, Indonesia',
#  'Banda Sea',
#  'Solomon Islands',
#  'Taiwan region',
#  'Kodiak Island region, Alaska',
#  'Oaxaca, Mexico',
#  'Vanuatu',
#  'Vanuatu',
#  'Vanuatu',
#  'Vanuatu',
#  'Macquarie Island region',
#  'Fox Islands, Aleutian Islands, Alaska',
#  'Kuril Islands',
#  'Kuril Islands',
#  'Vanuatu',
#  'Rat Islands, Aleutian Islands, Alaska',
#  'Valparaiso, Chile',
#  'Hindu Kush region, Afghanistan',
#  'near the coast of Antofagasta, Chile',
#  'Rat Islands, Aleutian Islands, Alaska',
#  'Rat Islands, Aleutian Islands, Alaska',
#  'Kepulauan Sula, Indonesia',
#  'Nicobar Islands, India region',
#  'off the west coast of the South Island of New Zealand',
#  'Bougainville region, Papua New Guinea',
#  'Vanuatu',
#  'Guerrero, Mexico',
#  'Kuril Islands',
#  'near the west coast of Honshu, Japan',
#  'South Sandwich Islands region',
#  'eastern Sea of Japan',
#  'northern Sumatra, Indonesia',
#  'Minahasa, Sulawesi, Indonesia',
#  '1964 Prince William Sound Earthquake, Alaska',
#  'south of the Fiji Islands',
#  'Java Sea',
#  'Peru-Brazil border region',
#  'Banda Sea',
#  'east of the Kuril Islands',
#  'Kuril Islands',
#  'Kuril Islands',
#  'Santa Cruz Islands',
#  'Santa Cruz Islands',
#  'Fiji region',
#  'southern Peru',
#  'Kepulauan Obi, Indonesia',
#  'Halmahera, Indonesia',
#  'Kermadec Islands, New Zealand',
#  'east of the Kuril Islands',
#  'eastern New Guinea region, Papua New Guinea',
#  'Taiwan region',
#  'Santiago Del Estero, Argentina',
#  'western Iran',
#  'south of Panama',
#  'Fiji region',
#  'Kepulauan Barat Daya, Indonesia',
#  'Guerrero, Mexico',
#  'Hokkaido, Japan region',
#  'near the east coast of Honshu, Japan',
#  'northern Mid-Atlantic Ridge',
#  'Araucania, Chile',
#  'South Sandwich Islands region',
#  'South Sandwich Islands region',
#  'Peru-Brazil border region',
#  'Peru-Brazil border region',
#  'Hokkaido, Japan region',
#  'Vanuatu',
#  'southeast of the Ryukyu Islands, Japan',
#  'southern Xinjiang, China',
#  'Kermadec Islands region',
#  'Kyushu, Japan',
#  'near the east coast of Honshu, Japan',
#  'near the east coast of Honshu, Japan',
#  'Antofagasta, Chile',
#  'south of the Fiji Islands',
#  'near the coast of northern Peru',
#  'off the coast of Araucania, Chile',
#  'Araucania, Chile',
#  'Aisen, Chile',
#  '1960 Great Chilean Earthquake (Valdivia Earthquake)',
#  'Araucania, Chile',
#  'Bio-Bio, Chile',
#  'Bio-Bio, Chile',
#  'off the east coast of Honshu, Japan',
#  'off the east coast of Honshu, Japan',
#  'near the coast of southern Peru',
#  'South Sandwich Islands region',
#  'Kermadec Islands region',
#  'The 1959 Hebgen Lake Earthquake, Montana',
#  'Solomon Islands',
#  'Taiwan region',
#  'Tarapaca, Chile',
#  'near the east coast of the Kamchatka Peninsula, Russia',
#  'off the east coast of Honshu, Japan',
#  'Kuril Islands',
#  'Kuril Islands',
#  'southern Peru',
#  'Southeastern Alaska',
#  'northern Alaska',
#  'southwestern Ryukyu Islands, Japan',
#  'near the coast of Ecuador',
#  'near the coast of southern Peru',
#  'Santa Cruz Islands',
#  'central Mongolia',
#  'Potosi, Bolivia',
#  'near the east coast of the Kamchatka Peninsula, Russia',
#  'Fiji region',
#  'Philippine Islands region',
#  'Guerrero, Mexico',
#  "Chitinskaya Oblast', Russia",
#  'Biak region, Indonesia',
#  'western Turkey',
#  'Dodecanese Islands, Greece',
#  'Dodecanese Islands, Greece',
#  'Tonga',
#  'south of Alaska',
#  'Fox Islands, Aleutian Islands, Alaska',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'Fox Islands, Aleutian Islands, Alaska',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'near the coast of Nicaragua',
#  'near the east coast of Honshu, Japan',
#  'Dodecanese Islands, Greece',
#  'central Afghanistan',
#  'Fiji region',
#  'Izu Islands, Japan region',
#  'near the coast of Ecuador',
#  'south of Tonga',
#  'New Britain region, Papua New Guinea',
#  'Volcano Islands, Japan region',
#  'Nicobar Islands, India region',
#  'offshore Coquimbo, Chile',
#  'western Sichuan, China',
#  'Mindanao, Philippines',
#  'South Indian Ocean',
#  'near the east coast of the Kamchatka Peninsula, Russia',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'Kermadec Islands region',
#  'Auckland Islands, New Zealand region',
#  'The 1954 Fairview Peak Earthquake, Nevada',
#  'Baja California, Mexico',
#  'Owen Fracture Zone region',
#  'Strait of Gibraltar',
#  'Gansu, China',
#  'Volcano Islands, Japan region',
#  'Peru-Ecuador border region',
#  'off the east coast of Honshu, Japan',
#  'Vanuatu',
#  'Vanuatu',
#  'Bio-Bio, Chile',
#  'New Britain region, Papua New Guinea',
#  'Saint Lucia region, Windward Islands',
#  'western Turkey',
#  'Near Islands, Aleutian Islands, Alaska',
#  'Solomon Islands',
#  'off the east coast of the Kamchatka Peninsula, Russia',
#  'eastern Xizang',
#  '6km WNW of Grapevine, CA',
#  'Philippine Islands region',
#  'Hokkaido, Japan region',
#  'Kepulauan Barat Daya, Indonesia',
#  'South Indian Ocean',
#  'Taiwan',
#  'Taiwan',
#  'eastern Xizang',
#  'Kuril Islands',
#  'Taiwan',
#  'Taiwan',
#  'Taiwan',
#  'central Turkey',
#  'Bonin Islands, Japan region',
#  'southeastern Sakha, Russia',
#  'Guerrero, Mexico',
#  'Tonga',
#  'Antofagasta, Chile',
#  'Vanuatu',
#  'Banda Sea',
#  'Guatemala',
#  'Banda Sea',
#  'Costa Rica',
#  'Papua, Indonesia',
#  '1950 Assam-Tibet Earthquake',
#  'Santiago Del Estero, Argentina',
#  'Vanuatu',
#  'Hokkaido, Japan region',
#  'Luzon, Philippines',
#  'Tierra del Fuego, Magallanes, Chile',
#  'Tierra del Fuego, Magallanes, Chile',
#  'Haida Gwaii, Canada',
#  'Tajikistan',
#  'Mariana Islands region',
#  'Molucca Sea',
#  'Hindu Kush region, Afghanistan',
#  'southern Xinjiang, China',
#  'Turkmenistan',
#  'Tonga',
#  'Salta, Argentina',
#  'western Sichuan, China',
#  'Alaska Peninsula',
#  'near the south coast of western Honshu, Japan',
#  'Philippine Islands region',
#  'Seram, Indonesia',
#  'Dodecanese Islands, Greece',
#  'Fiji region',
#  'Panay, Philippines',
#  'eastern Sea of Japan',
#  'central Peru',
#  'Central Alaska',
#  'southern Greece',
#  'eastern Xizang-India border region',
#  'Mariana Islands region',
#  'Mariana Islands region',
#  'Molucca Sea',
#  'Leyte, Philippines',
#  'near the north coast of Papua, Indonesia',
#  'near the north coast of Papua, Indonesia',
#  'North Island of New Zealand',
#  'Qinghai-Sichuan border region, China',
#  '1946 Nankai Earthquake, Japan',
#  'Kyrgyzstan',
#  'Andreanof Islands, Aleutian Islands, Alaska',
#  'New Ireland region, Papua New Guinea',
#  'Myanmar',
#  'Dominican Republic region',
#  'Dominican Republic region',
#  'Vancouver Island, Canada region',
#  'southern Sumatra, Indonesia',
#  '1946 Aleutian Islands (Unimak Island) Earthquake, Alaska',
#  'off the coast of Pakistan',
#  ...]

# %%
d = {}
for i in places:
  if i not in d.keys():
    d[i] = 1
  else:
    d[i] += 1
f = None
e = 1234567654315267
for a, b in d.items():
  if b < e:
    e = b
    f = a

a
# Out:
# 'offshore Miranda, Venezuela'
